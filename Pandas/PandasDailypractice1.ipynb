# %% [markdown]
# Step 1. Import the necessary libraries

# %% [markdown]
# Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Step 2. Create a data dictionary that looks like the DataFrame below

# %%
dict = {'evolution': ["Ivysaur","Charmeleon","watortle","Metapod"],
        'hp':[45,38,44,45],
        'name': ["Bulbasau","Charmander","Squirtle","Caterpie"],
        'pokedex':["yes","no","yes","no"],
        'type':["grass","fire","water","bug"]}
dp= pd.DataFrame(dict)
dp
# Out:
#     evolution  hp        name pokedex   type
# 0     Ivysaur  45    Bulbasau     yes  grass
# 1  Charmeleon  38  Charmander      no   fire
# 2    watortle  44    Squirtle     yes  water
# 3     Metapod  45    Caterpie      no    bug

# %% [markdown]
# Assign it to a variable called pokemon

# %%
dict = {'evolution': ["Ivysaur","Charmeleon","watortle","Metapod"],
        'hp':[45,38,44,45],
        'name': ["Bulbasau","Charmander","Squirtle","Caterpie"],
        'pokedex':["yes","no","yes","no"],
        'type':["grass","fire","water","bug"]}
dp= pd.DataFrame(dict)
#assign to Pokeman
Pokeman = dp
Pokeman
# Out:
#     evolution  hp        name pokedex   type
# 0     Ivysaur  45    Bulbasau     yes  grass
# 1  Charmeleon  38  Charmander      no   fire
# 2    watortle  44    Squirtle     yes  water
# 3     Metapod  45    Caterpie      no    bug

# %% [markdown]
# Step 4. Ops...it seems the DataFrame columns are in alphabetical order. Place the order of the columns as name, type, hp, evolution, pokedex

# %%
cols = ['name', 'type', 'hp', 'evolution', 'pokedex']
Pokeman = Pokeman[cols]
Pokeman
# Out:
#          name   type  hp   evolution pokedex
# 0    Bulbasau  grass  45     Ivysaur     yes
# 1  Charmander   fire  38  Charmeleon      no
# 2    Squirtle  water  44    watortle     yes
# 3    Caterpie    bug  45     Metapod      no

# %% [markdown]
# Step 5. Add another column called place, and insert what you have in mind.

# %%
# Using DataFrame.insert() to add a column
Pokeman.insert(5, "Place", ['Kenya', 'Uganda', 'TZ', 'Rwanda'], True)

# %% [markdown]
# Step 6. Present the type of each column

# %%
Pokeman.iloc[:4,1]
# Out:
# 0    grass
# 1     fire
# 2    water
# 3      bug
# Name: type, dtype: object

# %% [markdown]
# BONUS: Create your own question and answer it.
