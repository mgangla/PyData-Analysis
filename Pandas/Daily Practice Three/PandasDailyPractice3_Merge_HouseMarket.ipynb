# %%
import pandas as pd
import numpy as np
import random

# %% [markdown]
# Step 2. Create 3 differents Series, each of length 100, as follows:
# The first a random number from 1 to 4
# The second a random number from 1 to 3
# The third a random number from 10,000 to 30,000

# %%
series1 = pd.Series(np.random.randint(1, high=5, size=100, dtype='l'))
series2 = pd.Series(np.random.randint(1, high=4, size=100, dtype='l'))
series3 = pd.Series(np.random.randint(10000, high=30001, size=100, dtype='l'))

# %%
series1

series3
# Out:
# 0     18781
# 1     21590
# 2     12728
# 3     26648
# 4     21232
#       ...
# 95    19372
# 96    14201
# 97    24315
# 98    20759
# 99    12899
# Length: 100, dtype: int64

# %%
series2
# Out:
# 0     2
# 1     2
# 2     3
# 3     1
# 4     1
#      ..
# 95    1
# 96    3
# 97    3
# 98    1
# 99    3
# Length: 100, dtype: int64

# %%
series3
# Out:
# 0     18781
# 1     21590
# 2     12728
# 3     26648
# 4     21232
#       ...
# 95    19372
# 96    14201
# 97    24315
# 98    20759
# 99    12899
# Length: 100, dtype: int64

# %% [markdown]
# Step 3. Let's create a DataFrame by joinning the Series by column

# %%
df_House = pd.concat([series1, series2, series3], axis=1)

# %%
df_House
# Out:
#     0  1      2
# 0   3  2  18781
# 1   4  2  21590
# 2   4  3  12728
# 3   4  1  26648
# 4   4  1  21232
# .. .. ..    ...
# 95  4  1  19372
# 96  4  3  14201
# 97  4  3  24315
# 98  1  1  20759
# 99  3  3  12899
#
# [100 rows x 3 columns]

# %% [markdown]
# Step 4. Change the name of the columns to bedrs, bathrs, price_sqr_meter

# %%
df_House.rename(columns = {0: 'bedrs', 1: 'bathrs', 2: 'price_sqr_meter'}, inplace=True)

# %%
df_House
# Out:
#     bedrs  bathrs  price_sqr_meter
# 0       3       2            18781
# 1       4       2            21590
# 2       4       3            12728
# 3       4       1            26648
# 4       4       1            21232
# ..    ...     ...              ...
# 95      4       1            19372
# 96      4       3            14201
# 97      4       3            24315
# 98      1       1            20759
# 99      3       3            12899
#
# [100 rows x 3 columns]

# %% [markdown]
# Step 5. Create a one column DataFrame with the values of the 3 Series and assign it to 'bigcolumn'

# %%
bigcolumn = pd.concat([series1,series2,series3])

# %%
bigcolumn
# Out:
# 0         3
# 1         4
# 2         4
# 3         4
# 4         4
#       ...
# 95    19372
# 96    14201
# 97    24315
# 98    20759
# 99    12899
# Length: 300, dtype: int64

# %% [markdown]
# Step 6. Oops, it seems it is going only until index 99. Is it true?

# %% [markdown]
# Step 7. Reindex the DataFrame so it goes from 0 to 299

# %%
bigcolumn.reset_index(drop=True,inplace=True)

# %%
bigcolumn
# Out:
# 0          3
# 1          4
# 2          4
# 3          4
# 4          4
#        ...
# 295    19372
# 296    14201
# 297    24315
# 298    20759
# 299    12899
# Length: 300, dtype: int64
