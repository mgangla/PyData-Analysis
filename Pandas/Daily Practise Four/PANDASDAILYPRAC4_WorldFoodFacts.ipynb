# %%
import pandas as pd
import numpy as np

# %% [markdown]
# . Use the tsv file and assign it to a dataframe called food

# %%
pd.read_csv('/content/en.openfoodfacts.org.products.tsv',sep='\t')
# Out:
# <ipython-input-4-66823e260135>:1: DtypeWarning: Columns (17,18,26,28,37,38,39,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv('/content/en.openfoodfacts.org.products.tsv',sep='\t')
#               code                                                url  \
# 0             3087  http://world-en.openfoodfacts.org/product/0000...
# 1             4530  http://world-en.openfoodfacts.org/product/0000...
# 2             4559  http://world-en.openfoodfacts.org/product/0000...
# 3            16087  http://world-en.openfoodfacts.org/product/0000...
# 4            16094  http://world-en.openfoodfacts.org/product/0000...
# ...            ...                                                ...
# 17169  21130070107  http://world-en.openfoodfacts.org/product/0021...
# 17170  21130070244  http://world-en.openfoodfacts.org/product/0021...
# 17171  21130070275  http://world-en.openfoodfacts.org/product/0021...
# 17172  21130070282  http://world-en.openfoodfacts.org/product/0021...
# 17173  21130070534  http://world-en.openfoodfacts.org/product/0021...
#
#                           creator   created_t      created_datetime  \
# 0      openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1                 usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2                 usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3                 usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4                 usda-ndb-import  1489055653  2017-03-09T10:34:13Z
# ...                           ...         ...                   ...
# 17169             usda-ndb-import  1489092820  2017-03-09T20:53:40Z
# 17170             usda-ndb-import  1489138653  2017-03-10T09:37:33Z
# 17171                      bdwyer  1488082926  2017-02-26T04:22:06Z
# 17172             usda-ndb-import  1489140064  2017-03-10T10:01:04Z
# 17173             usda-ndb-import  1489074083  2017-03-09T15:41:23Z
#
#        last_modified_t last_modified_datetime                    product_name  \
# 0           1474103893   2016-09-17T09:18:13Z              Farine de blé noir
# 1           1489069957   2017-03-09T14:32:37Z  Banana Chips Sweetened (Whole)
# 2           1489069957   2017-03-09T14:32:37Z                         Peanuts
# 3           1489055731   2017-03-09T10:35:31Z          Organic Salted Nut Mix
# 4           1489055653   2017-03-09T10:34:13Z                 Organic Polenta
# ...                ...                    ...                             ...
# 17169       1489092820   2017-03-09T20:53:40Z                            Milk
# 17170       1489138654   2017-03-10T09:37:34Z                  Holiday Eggnog
# 17171       1488084073   2017-02-26T04:41:13Z           Chocolate Lowfat Milk
# 17172       1489140065   2017-03-10T10:01:05Z             2% Reduced Fat Milk
# 17173       1489074083   2017-03-09T15:41:23Z           Cranberry Apple Drink
#
#       generic_name           quantity  ... fruits-vegetables-nuts_100g  \
# 0              NaN                1kg  ...                         NaN
# 1              NaN                NaN  ...                         NaN
# 2              NaN                NaN  ...                         NaN
# 3              NaN                NaN  ...                         NaN
# 4              NaN                NaN  ...                         NaN
# ...            ...                ...  ...                         ...
# 17169          NaN                NaN  ...                         NaN
# 17170          NaN                NaN  ...                         NaN
# 17171          NaN  1 GALLON (3.78 L)  ...                         NaN
# 17172          NaN                NaN  ...                         NaN
# 17173          NaN                NaN  ...                         NaN
#
#       fruits-vegetables-nuts-estimate_100g collagen-meat-protein-ratio_100g  \
# 0                                      NaN                              NaN
# 1                                      NaN                              NaN
# 2                                      NaN                              NaN
# 3                                      NaN                              NaN
# 4                                      NaN                              NaN
# ...                                    ...                              ...
# 17169                                  NaN                              NaN
# 17170                                  NaN                              NaN
# 17171                                  NaN                              NaN
# 17172                                  NaN                              NaN
# 17173                                  NaN                              NaN
#
#       cocoa_100g chlorophyl_100g carbon-footprint_100g  \
# 0            NaN             NaN                   NaN
# 1            NaN             NaN                   NaN
# 2            NaN             NaN                   NaN
# 3            NaN             NaN                   NaN
# 4            NaN             NaN                   NaN
# ...          ...             ...                   ...
# 17169        NaN             NaN                   NaN
# 17170        NaN             NaN                   NaN
# 17171        NaN             NaN                   NaN
# 17172        NaN             NaN                   NaN
# 17173        NaN             NaN                   NaN
#
#       nutrition-score-fr_100g nutrition-score-uk_100g glycemic-index_100g  \
# 0                         NaN                     NaN                 NaN
# 1                        14.0                    14.0                 NaN
# 2                         0.0                     0.0                 NaN
# 3                        12.0                    12.0                 NaN
# 4                         NaN                     NaN                 NaN
# ...                       ...                     ...                 ...
# 17169                     1.0                     1.0                 NaN
# 17170                     6.0                     6.0                 NaN
# 17171                     3.0                     3.0                 NaN
# 17172                     0.0                     0.0                 NaN
# 17173                     NaN                     NaN                 NaN
#
#       water-hardness_100g
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 17169                 NaN
# 17170                 NaN
# 17171                 NaN
# 17172                 NaN
# 17173                 NaN
#
# [17174 rows x 163 columns]

# %%
food=pd.read_csv('/content/en.openfoodfacts.org.products.tsv',sep='\t')
# Out:
# <ipython-input-5-84c0f576faec>:1: DtypeWarning: Columns (26,28,37,38,39,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   food=pd.read_csv('/content/en.openfoodfacts.org.products.tsv',sep='\t')

# %% [markdown]
# Step 4. See the first 5 entries

# %%
food.head()
# Out:
#     code                                                url  \
# 0   3087  http://world-en.openfoodfacts.org/product/0000...
# 1   4530  http://world-en.openfoodfacts.org/product/0000...
# 2   4559  http://world-en.openfoodfacts.org/product/0000...
# 3  16087  http://world-en.openfoodfacts.org/product/0000...
# 4  16094  http://world-en.openfoodfacts.org/product/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3             usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4             usda-ndb-import  1489055653  2017-03-09T10:34:13Z
#
#    last_modified_t last_modified_datetime                    product_name  \
# 0       1474103893   2016-09-17T09:18:13Z              Farine de blé noir
# 1       1489069957   2017-03-09T14:32:37Z  Banana Chips Sweetened (Whole)
# 2       1489069957   2017-03-09T14:32:37Z                         Peanuts
# 3       1489055731   2017-03-09T10:35:31Z          Organic Salted Nut Mix
# 4       1489055653   2017-03-09T10:34:13Z                 Organic Polenta
#
#   generic_name quantity  ... fruits-vegetables-nuts_100g  \
# 0          NaN      1kg  ...                         NaN
# 1          NaN      NaN  ...                         NaN
# 2          NaN      NaN  ...                         NaN
# 3          NaN      NaN  ...                         NaN
# 4          NaN      NaN  ...                         NaN
#
#   fruits-vegetables-nuts-estimate_100g collagen-meat-protein-ratio_100g  \
# 0                                  NaN                              NaN
# 1                                  NaN                              NaN
# 2                                  NaN                              NaN
# 3                                  NaN                              NaN
# 4                                  NaN                              NaN
#
#   cocoa_100g chlorophyl_100g carbon-footprint_100g nutrition-score-fr_100g  \
# 0        NaN             NaN                   NaN                     NaN
# 1        NaN             NaN                   NaN                    14.0
# 2        NaN             NaN                   NaN                     0.0
# 3        NaN             NaN                   NaN                    12.0
# 4        NaN             NaN                   NaN                     NaN
#
#   nutrition-score-uk_100g glycemic-index_100g water-hardness_100g
# 0                     NaN                 NaN                 NaN
# 1                    14.0                 NaN                 NaN
# 2                     0.0                 NaN                 NaN
# 3                    12.0                 NaN                 NaN
# 4                     NaN                 NaN                 NaN
#
# [5 rows x 163 columns]

# %% [markdown]
# Step 5. What is the number of observations in the dataset?

# %%
food.shape
# Out:
# (18767, 163)

# %% [markdown]
# Step 6. What is the number of columns in the dataset?

# %%
food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18767 entries, 0 to 18766
# Columns: 163 entries, code to water-hardness_100g
# dtypes: float64(109), int64(3), object(51)
# memory usage: 23.3+ MB

# %% [markdown]
# Step 7. Print the name of all the columns.

# %%
food.columns
# Out:
# Index(['code', 'url', 'creator', 'created_t', 'created_datetime',
#        'last_modified_t', 'last_modified_datetime', 'product_name',
#        'generic_name', 'quantity',
#        ...
#        'fruits-vegetables-nuts_100g', 'fruits-vegetables-nuts-estimate_100g',
#        'collagen-meat-protein-ratio_100g', 'cocoa_100g', 'chlorophyl_100g',
#        'carbon-footprint_100g', 'nutrition-score-fr_100g',
#        'nutrition-score-uk_100g', 'glycemic-index_100g',
#        'water-hardness_100g'],
#       dtype='object', length=163)

# %% [markdown]
# Step 8. What is the name of 105th column?

# %%
food.columns[105]
# Out:
# '-fructose_100g'

# %% [markdown]
# Step 9. What is the type of the observations of the 105th column?

# %%
food.dtypes[105]
# Out:
# dtype('float64')

# %% [markdown]
# Step 10. How is the dataset indexed?

# %%
food.index
# Out:
# RangeIndex(start=0, stop=18767, step=1)

# %% [markdown]
# Step 11. What is the product name of the 19th observation?

# %%
food["product_name"][19]
# Out:
# 'Organic Oat Groats'
