# %% [markdown]
# <a href="https://colab.research.google.com/github/mgangla/PyData-Analysis/blob/main/CarsDemoCodeAlong.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# load cars

# %%
pd.read_csv('/content/car_prices (1).csv')
# Out:
#        year     make                model        trim         body  \
# 0      2015      Kia              Sorento          LX          SUV
# 1      2015      Kia              Sorento          LX          SUV
# 2      2014      BMW             3 Series  328i SULEV        Sedan
# 3      2015    Volvo                  S60          T5        Sedan
# 4      2014      BMW  6 Series Gran Coupe        650i        Sedan
# ...     ...      ...                  ...         ...          ...
# 59993  2000      GMC          Sierra 1500          SL  Regular Cab
# 59994  2000    Honda               Accord       EX V6        Coupe
# 59995  2000    Honda               Accord          EX        Sedan
# 59996  2000  Hyundai              Elantra         GLS        Sedan
# 59997  2000    honda              odyssey          ex          NaN
#
#       transmission                vin state  condition  odometer  color  \
# 0        automatic  5xyktca69fg566472    ca        5.0   16639.0  white
# ...

# %%
cars = pd.read_csv('/content/car_prices (1).csv')

# %%
cars.head()
# Out:
#    year   make                model        trim   body transmission  \
# 0  2015    Kia              Sorento          LX    SUV    automatic
# 1  2015    Kia              Sorento          LX    SUV    automatic
# 2  2014    BMW             3 Series  328i SULEV  Sedan    automatic
# 3  2015  Volvo                  S60          T5  Sedan    automatic
# 4  2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca       45.0    1331.0   gray    black
# 3  yv1612tb4f1310987    ca       41.0   14282.0  white    black
# 4  wba6b2c57ed129731    ca       43.0    2641.0   gray    black
#
#                                    seller      mmr  sellingprice  \
# 0                 kia motors america  inc  20500.0       21500.0
# ...

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66618 entries, 0 to 66617
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   year          66618 non-null  int64
#  1   make          66348 non-null  object
#  2   model         66331 non-null  object
#  3   trim          66145 non-null  object
#  4   body          64632 non-null  object
#  5   transmission  58766 non-null  object
#  6   vin           66618 non-null  object
#  7   state         66618 non-null  object
#  8   condition     54826 non-null  float64
#  9   odometer      66543 non-null  float64
#  10  color         66460 non-null  object
#  11  interior      66460 non-null  object
#  12  seller        66618 non-null  object
#  13  mmr           66617 non-null  float64
#  14  sellingprice  66617 non-null  float64
#  15  saledate      66617 non-null  object
# dtypes: float64(4), int64(1), object(11)
# memory usage: 8.1+ MB

# %%
cars['year']=pd.to_datetime(cars['year'],format='%Y')

# %%
cars['sale_year']=cars['saledate'].str.split(expand=True)[3]

# %%
cars.head()
# Out:
#         year   make                model        trim   body transmission  \
# 0 2015-01-01    Kia              Sorento          LX    SUV    automatic
# 1 2015-01-01    Kia              Sorento          LX    SUV    automatic
# 2 2014-01-01    BMW             3 Series  328i SULEV  Sedan    automatic
# 3 2015-01-01  Volvo                  S60          T5  Sedan    automatic
# 4 2014-01-01    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca       45.0    1331.0   gray    black
# 3  yv1612tb4f1310987    ca       41.0   14282.0  white    black
# 4  wba6b2c57ed129731    ca       43.0    2641.0   gray    black
#
#                                    seller      mmr  sellingprice  \
# 0                 kia motors america  inc  20500.0       21500.0
# ...

# %%
cars['sale_month'] = cars['saledate'].str.split(expand = True)[1]

# %%
cars.head(3)
# Out:
#         year make     model        trim   body transmission  \
# 0 2015-01-01  Kia   Sorento          LX    SUV    automatic
# 1 2015-01-01  Kia   Sorento          LX    SUV    automatic
# 2 2014-01-01  BMW  3 Series  328i SULEV  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca       45.0    1331.0   gray    black
#
#                                    seller      mmr  sellingprice  \
# 0                 kia motors america  inc  20500.0       21500.0
# 1                 kia motors america  inc  20800.0       21500.0
# 2  financial services remarketing (lease)  31900.0       30000.0
#
#                                   saledate sale_year sale_month
# 0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)      2014        Dec
# 1  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)      2014        Dec
# ...

# %%
cars['sale_month']=cars['sale_month'].fillna(0)
cars['sale_year']=cars['sale_year'].fillna(0)

# %%
cars['year'].astype("int")-cars['sale_year'].astype("int")
# Out:
# 0        1420070399999997986
# 1        1420070399999997986
# 2        1388534399999997985
# 3        1420070399999997985
# 4        1388534399999997986
#                 ...
# 66613    1167609599999997986
# 66614    1167609599999997986
# 66615    1167609599999997986
# 66616    1167609599999997986
# 66617    1167609600000000000
# Length: 66618, dtype: int64

# %%
cars['parsed_date'] = pd.to_datetime(cars['saledate'], utc=True, errors='coerce')

# %%
cars.head(3)
# Out:
#         year make     model        trim   body transmission  \
# 0 2015-01-01  Kia   Sorento          LX    SUV    automatic
# 1 2015-01-01  Kia   Sorento          LX    SUV    automatic
# 2 2014-01-01  BMW  3 Series  328i SULEV  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca       45.0    1331.0   gray    black
#
#                                    seller      mmr  sellingprice  \
# 0                 kia motors america  inc  20500.0       21500.0
# 1                 kia motors america  inc  20800.0       21500.0
# 2  financial services remarketing (lease)  31900.0       30000.0
#
#                                   saledate sale_year sale_month  \
# 0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)      2014        Dec
# 1  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)      2014        Dec
# ...

# %% [markdown]
# cars['year'].dtypes

# %%
cars.head(3)
# Out:
#         year make     model        trim   body transmission  \
# 0 2015-01-01  Kia   Sorento          LX    SUV    automatic
# 1 2015-01-01  Kia   Sorento          LX    SUV    automatic
# 2 2014-01-01  BMW  3 Series  328i SULEV  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca       45.0    1331.0   gray    black
#
#                                    seller      mmr  sellingprice  \
# 0                 kia motors america  inc  20500.0       21500.0
# 1                 kia motors america  inc  20800.0       21500.0
# 2  financial services remarketing (lease)  31900.0       30000.0
#
#                                   saledate sale_year sale_month  \
# 0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)      2014        Dec
# 1  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)      2014        Dec
# ...

# %% [markdown]
# Trend of sellingprice over year

# %%
cars['year'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
x=cars['year']
y=cars['sellingprice']

plt.figuresize=figsize=(14,6)

sns.lineplot(x="year",y="sellingprice",data=cars)
# Out:
# <Axes: xlabel='year', ylabel='sellingprice'>

# %%
corr_car= cars.corr()
# Out:
# <ipython-input-21-5fabcc11308d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_car= cars.corr()

# %%
sns.heatmap(corr_car,annot=True)
# Out:
# <Axes: >

# %%
target = cars['make'].value_counts().nlargest(10).index

# %%
filt_df = cars[cars['make'].isin(target)]

# %%
cars.head(10)
# Out:
#         year       make                model                       trim  \
# 0 2015-01-01        Kia              Sorento                         LX
# 1 2015-01-01        Kia              Sorento                         LX
# 2 2014-01-01        BMW             3 Series                 328i SULEV
# 3 2015-01-01      Volvo                  S60                         T5
# 4 2014-01-01        BMW  6 Series Gran Coupe                       650i
# 5 2015-01-01     Nissan               Altima                      2.5 S
# 6 2014-01-01        BMW                   M5                       Base
# 7 2014-01-01  Chevrolet                Cruze                        1LT
# 8 2014-01-01       Audi                   A4  2.0T Premium Plus quattro
# 9 2014-01-01  Chevrolet               Camaro                         LT
#
#           body transmission                vin state  condition  odometer  \
# 0          SUV    automatic  5xyktca69fg566472    ca        5.0   16639.0
# ...

# %%
sns.scatterplot(data=filt_df,x='sellingprice',y='mmr',hue="make")
plt.show()

# %%
sns.kdeplot(x='sellingprice',data=filt_df,hue='make',fill=True)
# Out:
# <Axes: xlabel='sellingprice', ylabel='Density'>
